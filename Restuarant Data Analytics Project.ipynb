# %% [markdown]
# **Data Analysis On Restuarant Dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Asus\\OneDrive\\Desktop\\power shheets\\tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ***Data Understandig***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df['total_bill'].describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
df['tip'].describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
df['sex'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['smoker'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
df['total_bill'].skew()       #right skewed
# Out:
# 1.1332130376158205

# %%
sns.histplot(df['total_bill'],kde=True)     #tip variable has outliers
plt.show()

# %%
df['tip'].skew()              #right skewed
# Out:
# 1.4654510370979401

# %%
sns.histplot(df['tip'],kde=True)     #tip variable has outliers
plt.show()

# %%
plt.boxplot(df['total_bill'])     #total_bill variable has outliers
plt.show()

# %%
plt.boxplot(df['tip'])     #tip variable has outliers
plt.show()

# %% [markdown]
# ***Data Preprocessing Or Data cleaning***

# %%
#treat missing values
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
#treat duplicate records
df.duplicated().sum()       #1 duplicate record
# Out:
# 1

# %%
df[df.duplicated()] #Threre is chance of a single person can visit multple times to the restuarant,
                    #keep as it is in this dataset
# Out:
#      total_bill  tip     sex smoker   day   time  size
# 202        13.0  2.0  Female    Yes  Thur  Lunch     2

# %%
#treat outliers
#retrain outliers because threre is chance of repetations

# %% [markdown]
# ***Data Analysis***

# %%
df['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
df.groupby("sex")["total_bill"].mean()
# Out:
# sex
# Female    18.056897
# Male      20.744076
# Name: total_bill, dtype: float64

# %%
df.groupby("sex")["total_bill"].max()
# Out:
# sex
# Female    44.30
# Male      50.81
# Name: total_bill, dtype: float64

# %%
df.groupby("sex")["total_bill"].min()
# Out:
# sex
# Female    3.07
# Male      7.25
# Name: total_bill, dtype: float64

# %%
sns.histplot(df["total_bill"])
plt.show()

# %%
df.groupby("sex")["tip"].max()
# Out:
# sex
# Female     6.5
# Male      10.0
# Name: tip, dtype: float64

# %%
df.groupby("sex")["tip"].mean()
# Out:
# sex
# Female    2.833448
# Male      3.089618
# Name: tip, dtype: float64

# %%
sns.catplot(x=df['sex'],y=df['tip'],kind='bar')
plt.show()

# %%
df.groupby("smoker")['total_bill'].mean()
# Out:
# smoker
# No     19.188278
# Yes    20.756344
# Name: total_bill, dtype: float64

# %%
df.groupby("day")['total_bill'].mean()
# Out:
# day
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Thur    17.682742
# Name: total_bill, dtype: float64

# %%
df.groupby("day")['total_bill'].sum()
# Out:
# day
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Thur    1096.33
# Name: total_bill, dtype: float64

# %%
df[]

# %%
sns.catplot(x="day",y='total_bill',data=df,kind='bar')
plt.show()

# %%
df.groupby('time')['total_bill'].mean()
# Out:
# time
# Dinner    20.797159
# Lunch     17.168676
# Name: total_bill, dtype: float64

# %%
sns.catplot(x="time",y='total_bill',data=df)
plt.show()

# %%
sns.catplot(x=df["day"],y=df['total_bill'],hue=df["sex"],kind='bar')
plt.show()

# %%
sns.catplot(x=df["time"],y=df['total_bill'],hue=df["sex"],kind='bar')
plt.show()

# %%
df['size'].sum()
# Out:
# 627

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
plt.plot(df['total_bill'],color='orange')
plt.show()

# %%
sns.catplot(x=df["smoker"],y=df['total_bill'],hue=df["sex"],kind='bar')
plt.show()

# %%
pd.crosstab(df['smoker'],df['time'])
# Out:
# time    Dinner  Lunch
# smoker
# No         106     45
# Yes         70     23

# %%
pd.crosstab(df['smoker'],df['day'])
# Out:
# day     Fri  Sat  Sun  Thur
# smoker
# No        4   45   57    45
# Yes      15   42   19    17

# %%
pd.crosstab(df['sex'],df['day'])
# Out:
# day     Fri  Sat  Sun  Thur
# sex
# Female    9   28   18    32
# Male     10   59   58    30

# %%
sns.pairplot(df)
plt.show()

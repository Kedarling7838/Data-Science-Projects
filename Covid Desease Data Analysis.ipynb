# %% [markdown]
# # COMPLETE DATA ANALYSIS OF COVID DESEASE DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
df=pd.read_csv("C:\\Users\\Asus\\OneDrive\\Desktop\\power shheets\\covid_related_disease_data.csv")
df
# Out:
#       Patient_ID  Age  Gender       Region Preexisting_Condition  \
# 0              1   69    Male  Hovedstaden               Obesity
# 1              2   38    Male     Sjælland                Asthma
# 2              3   41  Female   Syddanmark          Hypertension
# 3              4   81  Female  Hovedstaden                Asthma
# 4              5   50  Female   Syddanmark        Cardiovascular
# ...          ...  ...     ...          ...                   ...
# 2995        2996   43    Male  Nordjylland          Hypertension
# 2996        2997   36  Female   Syddanmark               Obesity
# 2997        2998   75  Female     Sjælland        Cardiovascular
# 2998        2999   45  Female  Hovedstaden                Asthma
# 2999        3000   83  Female  Midtjylland               Obesity
#
#      Date_of_Infection COVID_Strain  Symptoms  Severity Hospitalized  ...  \
# 0           2022-06-21        Delta      Mild  Moderate          Yes  ...
# ...

# %% [markdown]
# # Data Understanding

# %%
df.shape
# Out:
# (3000, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Patient_ID               3000 non-null   int64
#  1   Age                      3000 non-null   int64
#  2   Gender                   3000 non-null   object
#  3   Region                   3000 non-null   object
#  4   Preexisting_Condition    3000 non-null   object
#  5   Date_of_Infection        3000 non-null   object
#  6   COVID_Strain             3000 non-null   object
#  7   Symptoms                 3000 non-null   object
#  8   Severity                 3000 non-null   object
#  9   Hospitalized             3000 non-null   object
#  10  Hospital_Admission_Date  876 non-null    object
#  11  Hospital_Discharge_Date  876 non-null    object
#  12  ICU_Admission            3000 non-null   object
#  13  Ventilator_Support       3000 non-null   object
# ...

# %%
df.describe()
# Out:
#         Patient_ID          Age  Doses_Received          BMI
# count  3000.000000  3000.000000     3000.000000  3000.000000
# mean   1500.500000    53.944000        0.981667    25.096500
# std     866.169729    20.872919        1.154025     4.898435
# min       1.000000    18.000000        0.000000    10.200000
# 25%     750.750000    36.000000        0.000000    21.800000
# 50%    1500.500000    54.000000        0.000000    25.100000
# 75%    2250.250000    72.000000        2.000000    28.500000
# max    3000.000000    89.000000        3.000000    44.600000

# %%
continous=['Age','BMI']
descrete_categorical=['Gender', 'Region', 'Preexisting_Condition',
        'COVID_Strain', 'Symptoms', 'Severity','Hospitalized', 
       'ICU_Admission', 'Ventilator_Support', 'Recovered','Reinfection',  'Vaccination_Status',
       'Vaccine_Type',   'Long_COVID_Symptoms', 'Occupation', 'Smoking_Status', 'BMI']
descrete_counts=['Doses_Received']

# %%
df['Age'].describe()
# Out:
# count    3000.000000
# mean       53.944000
# std        20.872919
# min        18.000000
# 25%        36.000000
# 50%        54.000000
# 75%        72.000000
# max        89.000000
# Name: Age, dtype: float64

# %%
df['BMI'].describe()
# Out:
# count    3000.000000
# mean       25.096500
# std         4.898435
# min        10.200000
# 25%        21.800000
# 50%        25.100000
# 75%        28.500000
# max        44.600000
# Name: BMI, dtype: float64

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Female    1527
# Male      1473
# Name: Gender, dtype: int64

# %%
df['Region'].unique()
# Out:
# array(['Hovedstaden', 'Sjælland', 'Syddanmark', 'Nordjylland',
#        'Midtjylland'], dtype=object)

# %%
df['Region'].value_counts()
# Out:
# Midtjylland    628
# Hovedstaden    612
# Sjælland       609
# Syddanmark     597
# Nordjylland    554
# Name: Region, dtype: int64

# %%
df['Preexisting_Condition'].unique()
# Out:
# array(['Obesity', 'Asthma', 'Hypertension', 'Cardiovascular', 'Diabetes',
#        'None'], dtype=object)

# %%
df['Preexisting_Condition'].value_counts()
# Out:
# Cardiovascular    533
# Obesity           511
# Diabetes          511
# Hypertension      493
# Asthma            483
# None              469
# Name: Preexisting_Condition, dtype: int64

# %%
df['COVID_Strain'].unique()
# Out:
# array(['Delta', 'XBB.1.5', 'Beta', 'Omicron', 'Alpha'], dtype=object)

# %%
df['COVID_Strain'].value_counts()
# Out:
# Beta       622
# Omicron    616
# Delta      600
# XBB.1.5    583
# Alpha      579
# Name: COVID_Strain, dtype: int64

# %%
df['Symptoms'].unique()
# Out:
# array(['Mild', 'Severe', 'Moderate'], dtype=object)

# %%
df['Symptoms'].value_counts()
# Out:
# Severe      1012
# Mild        1010
# Moderate     978
# Name: Symptoms, dtype: int64

# %%
df['Severity'].unique()
# Out:
# array(['Moderate', 'High', 'Critical', 'Low'], dtype=object)

# %%
df['Severity'].value_counts()
# Out:
# Moderate    791
# High        766
# Low         732
# Critical    711
# Name: Severity, dtype: int64

# %%
df['Hospitalized'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Hospitalized'].value_counts()
# Out:
# No     2124
# Yes     876
# Name: Hospitalized, dtype: int64

# %%
df['ICU_Admission'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['ICU_Admission'].value_counts()
# Out:
# No     2838
# Yes     162
# Name: ICU_Admission, dtype: int64

# %%
df['Ventilator_Support'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Ventilator_Support'].value_counts()
# Out:
# No     2912
# Yes      88
# Name: Ventilator_Support, dtype: int64

# %%
df['Reinfection'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Reinfection'].value_counts()
# Out:
# No     2715
# Yes     285
# Name: Reinfection, dtype: int64

# %%
df['Vaccination_Status'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Vaccination_Status'].value_counts()
# Out:
# No     1528
# Yes    1472
# Name: Vaccination_Status, dtype: int64

# %%
df['Vaccine_Type'].unique()
# Out:
# array(['None', 'Janssen', 'AstraZeneca', 'Moderna', 'Pfizer'],
#       dtype=object)

# %%
df['Vaccine_Type'].value_counts()
# Out:
# None           1809
# Pfizer          311
# AstraZeneca     295
# Janssen         293
# Moderna         292
# Name: Vaccine_Type, dtype: int64

# %%
df['Doses_Received'].value_counts()
# Out:
# 0    1528
# 3     497
# 1     496
# 2     479
# Name: Doses_Received, dtype: int64

# %%
df['Long_COVID_Symptoms'].unique()
# Out:
# array(['None', 'Fatigue', 'Chest Pain', 'Shortness of Breath',
#        'Brain Fog'], dtype=object)

# %%
df['Long_COVID_Symptoms'].value_counts()
# Out:
# None                   2780
# Fatigue                  62
# Brain Fog                59
# Chest Pain               52
# Shortness of Breath      47
# Name: Long_COVID_Symptoms, dtype: int64

# %%
df['Occupation'].unique()
# Out:
# array(['Healthcare', 'Unemployed', 'Office Worker', 'Student', 'Driver',
#        'Teacher'], dtype=object)

# %%
df['Occupation'].value_counts()
# Out:
# Student          533
# Office Worker    503
# Unemployed       497
# Driver           492
# Teacher          491
# Healthcare       484
# Name: Occupation, dtype: int64

# %%
df['Smoking_Status'].unique()
# Out:
# array(['Never', 'Former', 'Current'], dtype=object)

# %%
df['Smoking_Status'].value_counts()
# Out:
# Never      1019
# Current    1000
# Former      981
# Name: Smoking_Status, dtype: int64

# %%
sns.histplot(x=df['BMI'],kde=True)             #Data is normally distributed
plt.show()

# %%
sns.histplot(x=df['Age'],kde=True)                   
plt.show()

# %%
df['BMI'].skew()                      #Data is normally distributed
# Out:
# -0.02963944534739663

# %%
df['Age'].skew()                      #Data is normally distributed
# Out:
# -0.015164478848176254

# %%
sns.boxplot(df['BMI'])               #There is some outliers
plt.show()

# %%
sns.boxplot(df['Age'])               #There is No outliers
plt.show()

# %%
# treat outliers
Q1=df['BMI'].quantile(0.25)
print("Q1:",Q1)
Q3=df['BMI'].quantile(0.75)
print("Q3:",Q3)
IQR = Q3-Q1
print("IQR:",IQR)
# Out:
# Q1: 21.8
# Q3: 28.5
# IQR: 6.699999999999999

# %%
upper_limit=Q3+(1.5*IQR)
print("upper_limit",upper_limit)
lower_limit=Q1-(1.5*IQR)
print("lower_limit",lower_limit)
# Out:
# upper_limit 38.55
# lower_limit 11.750000000000002

# %%
df[(df['BMI']<lower_limit)|(df['BMI']>upper_limit)]                  #Outlier records
# Out:
#       Patient_ID  Age  Gender       Region Preexisting_Condition  \
# 52            53   87  Female  Midtjylland        Cardiovascular
# 94            95   38  Female  Midtjylland              Diabetes
# 96            97   86  Female  Hovedstaden          Hypertension
# 346          347   42    Male   Syddanmark                  None
# 359          360   55    Male  Midtjylland        Cardiovascular
# 561          562   19    Male   Syddanmark        Cardiovascular
# 610          611   63  Female   Syddanmark                Asthma
# 798          799   54  Female  Midtjylland        Cardiovascular
# 827          828   22    Male  Midtjylland                  None
# 848          849   64  Female  Hovedstaden          Hypertension
# 1160        1161   84  Female  Nordjylland               Obesity
# 1221        1222   23  Female  Nordjylland              Diabetes
# 1509        1510   69    Male  Midtjylland        Cardiovascular
# ...

# %% [markdown]
# # Data Cleaning

# %%
df=pd.read_csv("C:\\Users\\Asus\\OneDrive\\Desktop\\power shheets\\covid_related_disease_data.csv")          #Removing unimportant coumns
df=df.drop(['Patient_ID'], axis=1)
df
# Out:
#       Age  Gender       Region Preexisting_Condition Date_of_Infection  \
# 0      69    Male  Hovedstaden               Obesity        2022-06-21
# 1      38    Male     Sjælland                Asthma        2024-02-02
# 2      41  Female   Syddanmark          Hypertension        2023-05-28
# 3      81  Female  Hovedstaden                Asthma        2023-08-13
# 4      50  Female   Syddanmark        Cardiovascular        2023-03-10
# ...   ...     ...          ...                   ...               ...
# 2995   43    Male  Nordjylland          Hypertension        2022-10-19
# 2996   36  Female   Syddanmark               Obesity        2022-12-16
# 2997   75  Female     Sjælland        Cardiovascular        2023-09-30
# 2998   45  Female  Hovedstaden                Asthma        2023-06-06
# 2999   83  Female  Midtjylland               Obesity        2023-09-07
#
#      COVID_Strain  Symptoms  Severity Hospitalized Hospital_Admission_Date  \
# ...

# %% [markdown]
# ***Treat missing values***

# %%
df.isnull().mean()*100
# Out:
# Age                         0.000000
# Gender                      0.000000
# Region                      0.000000
# Preexisting_Condition       0.000000
# Date_of_Infection           0.000000
# COVID_Strain                0.000000
# Symptoms                    0.000000
# Severity                    0.000000
# Hospitalized                0.000000
# Hospital_Admission_Date    70.800000
# Hospital_Discharge_Date    70.800000
# ICU_Admission               0.000000
# Ventilator_Support          0.000000
# Recovered                   0.000000
# Date_of_Recovery           49.733333
# Reinfection                 0.000000
# Date_of_Reinfection        90.500000
# Vaccination_Status          0.000000
# Vaccine_Type                0.000000
# Doses_Received              0.000000
# Date_of_Last_Dose          50.933333
# Long_COVID_Symptoms         0.000000
# Occupation                  0.000000
# Smoking_Status              0.000000
# BMI                         0.000000
# dtype: float64

# %% [raw]
# -Threre is some variables have the missing values
#     Hospital_Admission_Date has the 70% missing values
#     Hospital_Discharge_Date has the 70% missing values
#     Date_of_Recovery has the 49% missing values
#     Date_of_Reinfection has the 90% missing values
#     Date_of_Last_Dose has the 50% missing values
# -These variaables have more thaan 30% missing vaues so i will drop these all variaables

# %%
df=df.drop(['Hospital_Admission_Date','Hospital_Discharge_Date','Date_of_Recovery','Date_of_Reinfection','Date_of_Last_Dose'], axis=1)
df
# Out:
#       Age  Gender       Region Preexisting_Condition Date_of_Infection  \
# 0      69    Male  Hovedstaden               Obesity        2022-06-21
# 1      38    Male     Sjælland                Asthma        2024-02-02
# 2      41  Female   Syddanmark          Hypertension        2023-05-28
# 3      81  Female  Hovedstaden                Asthma        2023-08-13
# 4      50  Female   Syddanmark        Cardiovascular        2023-03-10
# ...   ...     ...          ...                   ...               ...
# 2995   43    Male  Nordjylland          Hypertension        2022-10-19
# 2996   36  Female   Syddanmark               Obesity        2022-12-16
# 2997   75  Female     Sjælland        Cardiovascular        2023-09-30
# 2998   45  Female  Hovedstaden                Asthma        2023-06-06
# 2999   83  Female  Midtjylland               Obesity        2023-09-07
#
#      COVID_Strain  Symptoms  Severity Hospitalized ICU_Admission  \
# ...

# %%
df['Vaccine_Type'].unique()
# Out:
# array(['None', 'Janssen', 'AstraZeneca', 'Moderna', 'Pfizer'],
#       dtype=object)

# %%
df
# Out:
#       Age  Gender       Region Preexisting_Condition Date_of_Infection  \
# 0      69    Male  Hovedstaden               Obesity        2022-06-21
# 1      38    Male     Sjælland                Asthma        2024-02-02
# 2      41  Female   Syddanmark          Hypertension        2023-05-28
# 3      81  Female  Hovedstaden                Asthma        2023-08-13
# 4      50  Female   Syddanmark        Cardiovascular        2023-03-10
# ...   ...     ...          ...                   ...               ...
# 2995   43    Male  Nordjylland          Hypertension        2022-10-19
# 2996   36  Female   Syddanmark               Obesity        2022-12-16
# 2997   75  Female     Sjælland        Cardiovascular        2023-09-30
# 2998   45  Female  Hovedstaden                Asthma        2023-06-06
# 2999   83  Female  Midtjylland               Obesity        2023-09-07
#
#      COVID_Strain  Symptoms  Severity Hospitalized ICU_Admission  \
# ...

# %%
df.duplicated()           #There is no any duplicated values
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Length: 3000, dtype: bool

# %%
df.duplicated().sum()     #There is no any duplicated values
# Out:
# 0

# %% [markdown]
# ***Treat Outliers***

# %%
df['BMI']=df['BMI'].clip(lower=11.750000000000002,upper=38.55)
df['BMI']
# Out:
# 0       27.7
# 1       21.9
# 2       22.7
# 3       27.7
# 4       11.9
#         ...
# 2995    22.0
# 2996    27.8
# 2997    20.9
# 2998    19.3
# 2999    33.0
# Name: BMI, Length: 3000, dtype: float64

# %% [markdown]
# ***Replacing outliers***

# %%
sns.boxplot(df['BMI'])               
plt.show()

# %%
df=df.replace(to_replace=['None'], value=np.nan)
df.head()
# Out:
#    Age  Gender       Region Preexisting_Condition Date_of_Infection  \
# 0   69    Male  Hovedstaden               Obesity        2022-06-21
# 1   38    Male     Sjælland                Asthma        2024-02-02
# 2   41  Female   Syddanmark          Hypertension        2023-05-28
# 3   81  Female  Hovedstaden                Asthma        2023-08-13
# 4   50  Female   Syddanmark        Cardiovascular        2023-03-10
#
#   COVID_Strain Symptoms  Severity Hospitalized ICU_Admission  \
# 0        Delta     Mild  Moderate          Yes            No
# 1      XBB.1.5     Mild  Moderate           No            No
# 2         Beta     Mild      High          Yes           Yes
# 3        Delta   Severe      High           No            No
# 4        Delta     Mild      High           No            No
#
#   Ventilator_Support Recovered Reinfection Vaccination_Status Vaccine_Type  \
# 0                 No       Yes          No                Yes          NaN
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Region                      0
# Preexisting_Condition     469
# Date_of_Infection           0
# COVID_Strain                0
# Symptoms                    0
# Severity                    0
# Hospitalized                0
# ICU_Admission               0
# Ventilator_Support          0
# Recovered                   0
# Reinfection                 0
# Vaccination_Status          0
# Vaccine_Type             1809
# Doses_Received              0
# Long_COVID_Symptoms      2780
# Occupation                  0
# Smoking_Status              0
# BMI                         0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Age                       0.000000
# Gender                    0.000000
# Region                    0.000000
# Preexisting_Condition    15.633333
# Date_of_Infection         0.000000
# COVID_Strain              0.000000
# Symptoms                  0.000000
# Severity                  0.000000
# Hospitalized              0.000000
# ICU_Admission             0.000000
# Ventilator_Support        0.000000
# Recovered                 0.000000
# Reinfection               0.000000
# Vaccination_Status        0.000000
# Vaccine_Type             60.300000
# Doses_Received            0.000000
# Long_COVID_Symptoms      92.666667
# Occupation                0.000000
# Smoking_Status            0.000000
# BMI                       0.000000
# dtype: float64

# %% [raw]
# -Long_COVID_Symptoms variable has 92% missing values.
# -Vaccine_Type variable has 60% missing values.
# -Preexisting_Condition variable has 15% missing values.
# -Long_COVID_Symptoms and Vaccine_Type variables have more than 30% I will drop those both columns
# -Preexisting_Condition variable less missing values have to replace the original values

# %%
df=df.drop(['Long_COVID_Symptoms','Vaccine_Type'], axis=1)
df
# Out:
#       Age  Gender       Region Preexisting_Condition Date_of_Infection  \
# 0      69    Male  Hovedstaden               Obesity        2022-06-21
# 1      38    Male     Sjælland                Asthma        2024-02-02
# 2      41  Female   Syddanmark          Hypertension        2023-05-28
# 3      81  Female  Hovedstaden                Asthma        2023-08-13
# 4      50  Female   Syddanmark        Cardiovascular        2023-03-10
# ...   ...     ...          ...                   ...               ...
# 2995   43    Male  Nordjylland          Hypertension        2022-10-19
# 2996   36  Female   Syddanmark               Obesity        2022-12-16
# 2997   75  Female     Sjælland        Cardiovascular        2023-09-30
# 2998   45  Female  Hovedstaden                Asthma        2023-06-06
# 2999   83  Female  Midtjylland               Obesity        2023-09-07
#
#      COVID_Strain  Symptoms  Severity Hospitalized ICU_Admission  \
# ...

# %%
df.head()
# Out:
#    Age  Gender       Region Preexisting_Condition Date_of_Infection  \
# 0   69    Male  Hovedstaden               Obesity        2022-06-21
# 1   38    Male     Sjælland                Asthma        2024-02-02
# 2   41  Female   Syddanmark          Hypertension        2023-05-28
# 3   81  Female  Hovedstaden                Asthma        2023-08-13
# 4   50  Female   Syddanmark        Cardiovascular        2023-03-10
#
#   COVID_Strain Symptoms  Severity Hospitalized ICU_Admission  \
# 0        Delta     Mild  Moderate          Yes            No
# 1      XBB.1.5     Mild  Moderate           No            No
# 2         Beta     Mild      High          Yes           Yes
# 3        Delta   Severe      High           No            No
# 4        Delta     Mild      High           No            No
#
#   Ventilator_Support Recovered Reinfection Vaccination_Status  Doses_Received  \
# 0                 No       Yes          No                Yes               1
# ...

# %%
df['Preexisting_Condition'].mode()
# Out:
# 0    Cardiovascular
# Name: Preexisting_Condition, dtype: object

# %%
df['Preexisting_Condition'].fillna(df['Preexisting_Condition'].mode())
# Out:
# 0              Obesity
# 1               Asthma
# 2         Hypertension
# 3               Asthma
# 4       Cardiovascular
#              ...
# 2995      Hypertension
# 2996           Obesity
# 2997    Cardiovascular
# 2998            Asthma
# 2999           Obesity
# Name: Preexisting_Condition, Length: 3000, dtype: object

# %% [markdown]
# # Data Analysis

# %%
df['BMI'].mean()
# Out:
# 25.094350000000002

# %%
df['Age'].mean()
# Out:
# 53.944

# %%
df['Gender'].value_counts()
# Out:
# Female    1527
# Male      1473
# Name: Gender, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# Midtjylland    628
# Hovedstaden    612
# Sjælland       609
# Syddanmark     597
# Nordjylland    554
# Name: Region, dtype: int64

# %%
df.groupby('Preexisting_Condition')['BMI'].max()
# Out:
# Preexisting_Condition
# Asthma            38.55
# Cardiovascular    38.55
# Diabetes          38.55
# Hypertension      38.55
# Obesity           38.55
# Name: BMI, dtype: float64

# %%
df['Preexisting_Condition'].value_counts()
# Out:
# Cardiovascular    533
# Obesity           511
# Diabetes          511
# Hypertension      493
# Asthma            483
# Name: Preexisting_Condition, dtype: int64

# %%
df['Date_of_Infection'].value_counts()
# Out:
# 2023-05-02    11
# 2023-12-17    11
# 2024-01-14    11
# 2022-07-10    11
# 2023-07-26    10
#               ..
# 2024-01-10     1
# 2023-08-12     1
# 2024-03-20     1
# 2023-01-19     1
# 2022-06-18     1
# Name: Date_of_Infection, Length: 720, dtype: int64

# %%
sns.histplot(df['Age'])
plt.show()

# %%
df['COVID_Strain'].unique()
# Out:
# array(['Delta', 'XBB.1.5', 'Beta', 'Omicron', 'Alpha'], dtype=object)

# %%
df.groupby('Age')['COVID_Strain'].max()
# Out:
# Age
# 18    XBB.1.5
# 19    XBB.1.5
# 20    XBB.1.5
# 21    XBB.1.5
# 22    XBB.1.5
#        ...
# 85    XBB.1.5
# 86    XBB.1.5
# 87    XBB.1.5
# 88    XBB.1.5
# 89    XBB.1.5
# Name: COVID_Strain, Length: 72, dtype: object

# %%
df.groupby('Age')['COVID_Strain'].min()
# Out:
# Age
# 18    Alpha
# 19    Alpha
# 20    Alpha
# 21    Alpha
# 22    Alpha
#       ...
# 85    Alpha
# 86    Alpha
# 87    Alpha
# 88    Alpha
# 89    Alpha
# Name: COVID_Strain, Length: 72, dtype: object

# %%
df['COVID_Strain'].mode()
# Out:
# 0    Beta
# Name: COVID_Strain, dtype: object

# %%
sns.barplot(x=df['Age'],y=df['COVID_Strain'])
plt.show()

# %%
sns.barplot(x=df['Gender'],y=df['COVID_Strain'])
plt.show()

# %%
df['Symptoms'].unique
# Out:
# <bound method Series.unique of 0           Mild
# 1           Mild
# 2           Mild
# 3         Severe
# 4           Mild
#           ...
# 2995      Severe
# 2996    Moderate
# 2997      Severe
# 2998      Severe
# 2999    Moderate
# Name: Symptoms, Length: 3000, dtype: object>

# %%
sns.barplot(x=df['BMI'],y=df['Symptoms'])
plt.show()

# %%
sns.barplot(x=df['Region'],y=df['Symptoms'])
plt.show()

# %%
sns.barplot(x=df['Region'],y=df['COVID_Strain'])
plt.show()

# %%
df['Hospitalized'].value_counts()
# Out:
# No     2124
# Yes     876
# Name: Hospitalized, dtype: int64

# %%
df.groupby('Hospitalized')['Age'].mean()
# Out:
# Hospitalized
# No     54.094633
# Yes    53.578767
# Name: Age, dtype: float64

# %%
df.groupby('Hospitalized')['Region'].max()
# Out:
# Hospitalized
# No     Syddanmark
# Yes    Syddanmark
# Name: Region, dtype: object

# %%
df.groupby('Hospitalized')['Gender'].max()
# Out:
# Hospitalized
# No     Female
# Yes    Female
# Name: Gender, dtype: object

# %%
df.groupby('Hospitalized')['BMI'].mean()
# Out:
# Hospitalized
# No     25.149200
# Yes    24.961358
# Name: BMI, dtype: float64

# %%
df.groupby('ICU_Admission')['COVID_Strain'].max()
# Out:
# ICU_Admission
# No     XBB.1.5
# Yes    XBB.1.5
# Name: COVID_Strain, dtype: object

# %%
df.groupby('ICU_Admission')['Symptoms'].max()
# Out:
# ICU_Admission
# No     Severe
# Yes    Severe
# Name: Symptoms, dtype: object

# %%
df.groupby('ICU_Admission')['Age'].mean()
# Out:
# ICU_Admission
# No     54.040169
# Yes    52.259259
# Name: Age, dtype: float64

# %%
df.groupby('ICU_Admission')['BMI'].mean()
# Out:
# ICU_Admission
# No     25.131871
# Yes    24.437037
# Name: BMI, dtype: float64

# %%
plt.pie(df['Gender'].value_counts(),labels=['m','f'],autopct='%0.1f%%')
plt.show()

# %%
df.groupby('Preexisting_Condition')['Reinfection'].max()
# Out:
# Preexisting_Condition
# Asthma            Yes
# Cardiovascular    Yes
# Diabetes          Yes
# Hypertension      Yes
# Obesity           Yes
# Name: Reinfection, dtype: object

# %%
df.groupby('Preexisting_Condition')['Age'].mean()*100
# Out:
# Preexisting_Condition
# Asthma            5451.966874
# Cardiovascular    5324.390244
# Diabetes          5408.610568
# Hypertension      5449.290061
# Obesity           5435.029354
# Name: Age, dtype: float64

# %%
df['Vaccination_Status'].value_counts()
# Out:
# No     1528
# Yes    1472
# Name: Vaccination_Status, dtype: int64

# %%
df.groupby('Vaccination_Status')['Age'].mean()
# Out:
# Vaccination_Status
# No     53.840969
# Yes    54.050951
# Name: Age, dtype: float64

# %%
df.groupby('Vaccination_Status')['Age'].mean()*100
# Out:
# Vaccination_Status
# No     5384.096859
# Yes    5405.095109
# Name: Age, dtype: float64

# %%
plt.pie(df['Doses_Received'].value_counts(),labels=['None','First','Second','Third'],autopct='%0.1f%%')
plt.show()

# %%
sns.barplot(x=df['Occupation'],y=df['Doses_Received'])
plt.show()

# %%
sns.barplot(x=df['Reinfection'],y=df['Recovered'])
plt.show()

# %%
df.groupby('Recovered')['Age'].mean()
# Out:
# Recovered
# No     53.445710
# Yes    54.437003
# Name: Age, dtype: float64

# %%
df['Recovered'].value_counts()
# Out:
# Yes    1508
# No     1492
# Name: Recovered, dtype: int64

# %%
sns.barplot(x=df['Occupation'],y=df['Recovered'])
plt.show()

# %%
df.groupby('Smoking_Status')['Age'].mean()
# Out:
# Smoking_Status
# Current    53.494000
# Former     54.073394
# Never      54.261040
# Name: Age, dtype: float64

# %%
df.groupby('Smoking_Status')['BMI'].mean()
# Out:
# Smoking_Status
# Current    24.975100
# Former     25.315545
# Never      24.998430
# Name: BMI, dtype: float64

# %%
sns.catplot(x=df['Recovered'],y=df["Age"],hue=df['Region'],kind='bar')
plt.show()

# %%
sns.catplot(x=df['Doses_Received'],y=df["Age"],hue=df['Region'],kind='bar')
plt.show()

# %%
sns.catplot(x=df['Smoking_Status'],y=df["Age"],hue=df['Region'],kind='bar')
plt.show()

# %%
sns.pairplot(df)
plt.show()

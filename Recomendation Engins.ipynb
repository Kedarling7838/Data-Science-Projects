# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\Asus\\OneDrive\\Desktop\\power shheets\\movies.csv")
df.head()
# Out:
#    index                                    genres  \
# 0      0  Action Adventure Fantasy Science Fiction
# 1      1                  Adventure Fantasy Action
# 2      2                    Action Adventure Crime
# 3      3               Action Crime Drama Thriller
# 4      4          Action Adventure Science Fiction
#
#                                       title
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   4803 non-null   int64
#  1   genres  4775 non-null   object
#  2   title   4803 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 112.7+ KB

# %%
df.describe()
# Out:
#              index
# count  4803.000000
# mean   2401.000000
# std    1386.651002
# min       0.000000
# 25%    1200.500000
# 50%    2401.000000
# 75%    3601.500000
# max    4802.000000

# %%
df.isnull().sum()
# Out:
# index      0
# genres    28
# title      0
# dtype: int64

# %%
df.shape
# Out:
# (4803, 3)

# %%
df['genres'].isnull().sum()
# Out:
# np.int64(28)

# %%
df.dropna(inplace=True)
df
# Out:
#       index                                    genres  \
# 0         0  Action Adventure Fantasy Science Fiction
# 1         1                  Adventure Fantasy Action
# 2         2                    Action Adventure Crime
# 3         3               Action Crime Drama Thriller
# 4         4          Action Adventure Science Fiction
# ...     ...                                       ...
# 4797   4797                          Foreign Thriller
# 4798   4798                     Action Crime Thriller
# 4799   4799                            Comedy Romance
# 4800   4800             Comedy Drama Romance TV Movie
# 4802   4802                               Documentary
#
#                                          title
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...

# %%
#df[df['genres'].isnull().sum()]

# %%
df.shape
# Out:
# (4775, 3)

# %%
#Converting test data into feature vector
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer()
feature_vectors=vectorizer.fit_transform(df['genres'])

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['action', 'adventure', 'animation', 'comedy', 'crime',
#        'documentary', 'drama', 'family', 'fantasy', 'fiction', 'foreign',
#        'history', 'horror', 'movie', 'music', 'mystery', 'romance',
#        'science', 'thriller', 'tv', 'war', 'western'], dtype=object)

# %%
pd.DataFrame(vectorizer.fit_transform(df['genres']).toarray(),columns=vectorizer.get_feature_names_out())
# Out:
#         action  adventure  animation    comedy     crime  documentary  \
# 0     0.357203   0.412944        0.0  0.000000  0.000000          0.0
# 1     0.479529   0.554358        0.0  0.000000  0.000000          0.0
# 2     0.513227   0.593315        0.0  0.000000  0.620141          0.0
# 3     0.506334   0.000000        0.0  0.000000  0.611812          0.0
# 4     0.414336   0.478992        0.0  0.000000  0.000000          0.0
# ...        ...        ...        ...       ...       ...          ...
# 4770  0.000000   0.000000        0.0  0.000000  0.000000          0.0
# 4771  0.543227   0.000000        0.0  0.000000  0.656390          0.0
# 4772  0.000000   0.000000        0.0  0.601958  0.000000          0.0
# 4773  0.000000   0.000000        0.0  0.184296  0.000000          0.0
# 4774  0.000000   0.000000        0.0  0.000000  0.000000          1.0
#
#          drama  family   fantasy   fiction  ...  horror     movie  music  \
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(feature_vectors)
print(similarity)
# Out:
# [[1.         0.74490515 0.42833228 ... 0.         0.         0.        ]
#  [0.74490515 1.         0.57501586 ... 0.         0.         0.        ]
#  [0.42833228 0.57501586 1.         ... 0.         0.         0.        ]
#  ...
#  [0.         0.         0.         ... 1.         0.30616097 0.        ]
#  [0.         0.         0.         ... 0.30616097 1.         0.        ]
#  [0.         0.         0.         ... 0.         0.         1.        ]]

# %%
print(similarity.shape)
# Out:
# (4775, 4775)

# %%
df['title'].tolist()
# Out:
# ['Avatar',
#  "Pirates of the Caribbean: At World's End",
#  'Spectre',
#  'The Dark Knight Rises',
#  'John Carter',
#  'Spider-Man 3',
#  'Tangled',
#  'Avengers: Age of Ultron',
#  'Harry Potter and the Half-Blood Prince',
#  'Batman v Superman: Dawn of Justice',
#  'Superman Returns',
#  'Quantum of Solace',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'The Lone Ranger',
#  'Man of Steel',
#  'The Chronicles of Narnia: Prince Caspian',
#  'The Avengers',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Men in Black 3',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Amazing Spider-Man',
#  'Robin Hood',
#  'The Hobbit: The Desolation of Smaug',
#  'The Golden Compass',
#  'King Kong',
#  'Titanic',
#  'Captain America: Civil War',
#  'Battleship',
#  'Jurassic World',
#  'Skyfall',
#  'Spider-Man 2',
#  'Iron Man 3',
#  'Alice in Wonderland',
#  'X-Men: The Last Stand',
#  'Monsters University',
#  'Transformers: Revenge of the Fallen',
# ...

# %%
list_of_all_list=df['title'].tolist()
print(list_of_all_list)
# Out:
# ['Avatar', "Pirates of the Caribbean: At World's End", 'Spectre', 'The Dark Knight Rises', 'John Carter', 'Spider-Man 3', 'Tangled', 'Avengers: Age of Ultron', 'Harry Potter and the Half-Blood Prince', 'Batman v Superman: Dawn of Justice', 'Superman Returns', 'Quantum of Solace', "Pirates of the Caribbean: Dead Man's Chest", 'The Lone Ranger', 'Man of Steel', 'The Chronicles of Narnia: Prince Caspian', 'The Avengers', 'Pirates of the Caribbean: On Stranger Tides', 'Men in Black 3', 'The Hobbit: The Battle of the Five Armies', 'The Amazing Spider-Man', 'Robin Hood', 'The Hobbit: The Desolation of Smaug', 'The Golden Compass', 'King Kong', 'Titanic', 'Captain America: Civil War', 'Battleship', 'Jurassic World', 'Skyfall', 'Spider-Man 2', 'Iron Man 3', 'Alice in Wonderland', 'X-Men: The Last Stand', 'Monsters University', 'Transformers: Revenge of the Fallen', 'Transformers: Age of Extinction', 'Oz: The Great and Powerful', 'The Amazing Spider-Man 2', 'TRON: Legacy', 'Cars 2', 'Green La
# ...

# %%
movie_name=input("Enter your movie name")
# Out:
# Enter your movie name Avatar

# %%
import difflib
find_close_match=difflib.get_close_matches(movie_name,list_of_all_list)
print(find_close_match)
# Out:
# ['Avatar']

# %%
close_match=find_close_match[0]
print(close_match)
# Out:
# Avatar

# %%
movie_name=input("Enter your movie name")
# Out:
# Enter your movie name Robin Hood
# ['Robin Hood', 'Red Riding Hood', 'Son of God']

# %%
import difflib
find_close_match=difflib.get_close_matches(movie_name,list_of_all_list)
print(find_close_match)
# Out:
# ['Robin Hood', 'Red Riding Hood', 'Son of God']

# %%
index_of_the_movie=df[df.title==close_match]['index'].values[0]
print(index_of_the_movie)
# Out:
# 0

# %%
similarity_score=list(enumerate(similarity[index_of_the_movie]))
print(similarity_score)
# Out:
# [(0, np.float64(1.0)), (1, np.float64(0.7449051527492854)), (2, np.float64(0.42833227925901773)), (3, np.float64(0.18086421721481905)), (4, np.float64(0.8621097473197352)), (5, np.float64(0.7449051527492854)), (6, np.float64(0.0)), (7, np.float64(0.8621097473197352)), (8, np.float64(0.5278696477974326)), (9, np.float64(0.7449051527492854)), (10, np.float64(1.0)), (11, np.float64(0.38393877598725457)), (12, np.float64(0.7449051527492854)), (13, np.float64(0.32155943691176037)), (14, np.float64(1.0)), (15, np.float64(0.5278696477974326)), (16, np.float64(0.8621097473197352)), (17, np.float64(0.7449051527492854)), (18, np.float64(0.7041353940754864)), (19, np.float64(0.7449051527492854)), (20, np.float64(0.7449051527492854)), (21, np.float64(0.5460008269372254)), (22, np.float64(0.6536738054449669)), (23, np.float64(0.6536738054449669)), (24, np.float64(0.49451694487950215)), (25, np.float64(0.0)), (26, np.float64(0.8621097473197352)), (27, np.float64(0.8006439072287703)), (28, np.float
# ...

# %%
sorted_similar_movies=sorted(similarity_score,key=lambda x:x[1], reverse=True)
print(sorted_similar_movies)
# Out:
# [(0, np.float64(1.0)), (10, np.float64(1.0)), (14, np.float64(1.0)), (46, np.float64(1.0)), (61, np.float64(1.0)), (232, np.float64(1.0)), (813, np.float64(1.0)), (870, np.float64(1.0)), (3494, np.float64(1.0)), (238, np.float64(0.9583397219159037)), (618, np.float64(0.9583397219159037)), (1191, np.float64(0.9583397219159037)), (1296, np.float64(0.9583397219159037)), (1932, np.float64(0.9583397219159037)), (322, np.float64(0.9455457612310548)), (1230, np.float64(0.9455457612310548)), (1390, np.float64(0.9455457612310548)), (1652, np.float64(0.9455457612310548)), (419, np.float64(0.9340266363078027)), (420, np.float64(0.9340266363078027)), (426, np.float64(0.9340266363078027)), (72, np.float64(0.9181302700109866)), (728, np.float64(0.9107564656105375)), (1611, np.float64(0.9107564656105375)), (1802, np.float64(0.9107564656105375)), (2592, np.float64(0.9107564656105375)), (1192, np.float64(0.9033299878741525)), (2163, np.float64(0.9033299878741525)), (1936, np.float64(0.865585433737005
# ...

# %%
print("Movies suggested for you:\n")
i=1
for movie in sorted_similar_movies:
    index=movie[0]
    title_from_index=df[df.index==index]['title'].values
    if(i<=10):
        print(i,'.',title_from_index)
    i+=1
# Out:
# Movies suggested for you:
#
# 1 . ['Avatar']
# 2 . ['Superman Returns']
# 3 . ['Man of Steel']
# 4 . ['X-Men: Days of Future Past']
# 5 . ['Jupiter Ascending']
# 6 . ['The Wolverine']
# 7 . ['Superman']
# 8 . ['Superman II']
# 9 . ['Beastmaster 2: Through the Portal of Time']
# 10 . ['Teenage Mutant Ninja Turtles']

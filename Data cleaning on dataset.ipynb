# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Asus\\OneDrive\\Desktop\\power shheets\\stroke prediction.csv")
df
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0             0              0           No
# 1      30468    Male  58.0             1              0          Yes
# 2      16523  Female   8.0             0              0           No
# 3      56543  Female  70.0             0              0          Yes
# 4      46136    Male  14.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 43395  56196  Female  10.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43400 entries, 0 to 43399
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 43400 non-null  int64
#  1   gender             43400 non-null  object
#  2   age                43400 non-null  float64
#  3   hypertension       43400 non-null  int64
#  4   heart_disease      43400 non-null  int64
#  5   ever_married       43400 non-null  object
#  6   work_type          43400 non-null  object
#  7   Residence_type     43400 non-null  object
#  8   avg_glucose_level  43400 non-null  float64
#  9   bmi                41938 non-null  float64
#  10  smoking_status     30108 non-null  object
#  11  stroke             43400 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 4.0+ MB

# %%
df.describe()
# Out:
#                  id           age  hypertension  heart_disease  \
# count  43400.000000  43400.000000  43400.000000   43400.000000
# mean   36326.142350     42.217894      0.093571       0.047512
# std    21072.134879     22.519649      0.291235       0.212733
# min        1.000000      0.080000      0.000000       0.000000
# 25%    18038.500000     24.000000      0.000000       0.000000
# 50%    36351.500000     44.000000      0.000000       0.000000
# 75%    54514.250000     60.000000      0.000000       0.000000
# max    72943.000000     82.000000      1.000000       1.000000
#
#        avg_glucose_level           bmi        stroke
# count       43400.000000  41938.000000  43400.000000
# mean          104.482750     28.605038      0.018041
# std            43.111751      7.770020      0.133103
# min            55.000000     10.100000      0.000000
# 25%            77.540000     23.200000      0.000000
# 50%            91.580000     27.700000      0.000000
# ...

# %%
df.describe().all
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.all of                  id           age  hypertension  heart_disease  \
# count  43400.000000  43400.000000  43400.000000   43400.000000
# mean   36326.142350     42.217894      0.093571       0.047512
# std    21072.134879     22.519649      0.291235       0.212733
# min        1.000000      0.080000      0.000000       0.000000
# 25%    18038.500000     24.000000      0.000000       0.000000
# 50%    36351.500000     44.000000      0.000000       0.000000
# 75%    54514.250000     60.000000      0.000000       0.000000
# max    72943.000000     82.000000      1.000000       1.000000
#
#        avg_glucose_level           bmi        stroke
# count       43400.000000  41938.000000  43400.000000
# mean          104.482750     28.605038      0.018041
# std            43.111751      7.770020      0.133103
# min            55.000000     10.100000      0.000000
# 25%            77.540000     23.200000      0.000000
# ...

# %%
df['id'].unique()
# Out:
# array([30669, 30468, 16523, ..., 28375, 27973, 36271], dtype=int64)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['id'].isnull().sum()
# Out:
# 0

# %%
df['gender'].isnull().sum()
# Out:
# 0

# %%
df['hypertension'].isnull().sum()
# Out:
# 0

# %%
df['heart_disease'].isnull().sum()
# Out:
# 0

# %%
df['smoking_status'].isnull()
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 43395    False
# 43396    False
# 43397    False
# 43398    False
# 43399    False
# Name: smoking_status, Length: 43400, dtype: bool

# %%
df['smoking_status'].isnull().sum()
# Out:
# 13292

# %%
df['smoking_status'].mode()
# Out:
# 0    never smoked
# Name: smoking_status, dtype: object

# %%
n=df["smoking_status"].fillna(df["smoking_status"].mode()[0])
n
# Out:
# 0           never smoked
# 1           never smoked
# 2           never smoked
# 3        formerly smoked
# 4           never smoked
#               ...
# 43395       never smoked
# 43396    formerly smoked
# 43397    formerly smoked
# 43398       never smoked
# 43399       never smoked
# Name: smoking_status, Length: 43400, dtype: object

# %%
n[df["smoking_status"].isnull().sum()]
# Out:
# 'never smoked'

# %%
df['heart_disease']==0
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 43395    True
# 43396    True
# 43397    True
# 43398    True
# 43399    True
# Name: heart_disease, Length: 43400, dtype: bool

# %%
import seaborn as sns
sns.boxplot(df["id"])
# Out:
# <Axes: ylabel='id'>

# %%
sns.boxplot(df["avg_glucose_level"])
# Out:
# <Axes: ylabel='avg_glucose_level'>

# %%
sns.boxplot(df["bmi"])
# Out:
# <Axes: ylabel='bmi'>

# %%
Q1=df["bmi"].quantile(0.25)
print("Q1:",Q1)
Q3=df["bmi"].quantile(0.75)
print("Q3:",Q3)
IQR=Q3-Q1
print("IQR:",IQR)
lower_limit=Q1-(1.5*IQR)
print("lower_limit",lower_limit)
upper_limit=Q3+(1.5*IQR)
print("upper_limit",upper_limit)
# Out:
# Q1: 23.2
# Q3: 32.9
# IQR: 9.7
# lower_limit 8.65
# upper_limit 47.449999999999996

# %%
df[(df["bmi"]<lower_limit)|(df["bmi"]>upper_limit)]
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 5      32257  Female  47.0             0              0          Yes
# 9      28674  Female  74.0             1              0          Yes
# 21     72911  Female  57.0             1              0          Yes
# 86      1703  Female  52.0             0              0          Yes
# 94     38805  Female  37.0             0              0          Yes
# ...      ...     ...   ...           ...            ...          ...
# 43140  45966    Male  55.0             0              0          Yes
# 43188  35518    Male  72.0             0              0          Yes
# 43239  36167    Male  21.0             0              0           No
# 43355  57237  Female  46.0             0              0          Yes
# 43396   5450  Female  56.0             0              0          Yes
#
#            work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df['bmi']=df['bmi'].clip(lower=8.65,upper=47.449999999999996)
df
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0             0              0           No
# 1      30468    Male  58.0             1              0          Yes
# 2      16523  Female   8.0             0              0           No
# 3      56543  Female  70.0             0              0          Yes
# 4      46136    Male  14.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 43395  56196  Female  10.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level    bmi   smoking_status  \
# ...

# %%
sns.boxplot(df["bmi"])
# Out:
# <Axes: ylabel='bmi'>
